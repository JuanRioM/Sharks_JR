# %% [markdown]
# ![](img/shark.png)

# %% [markdown]
# # Global Shark Attack
#
# Fecha de entrega: _23:59 05/04/2021_

# %% [markdown]
# ### ¿En qué consiste este mini-proyecto?
#
# El objetivo de este mini-proyecto es que os enfrentéis a realizar un Exploratory Data Analysis por primera vez, antes del proyecto EDA.
#
# Durante este mini-proyecto deberás poner en práctica todo lo aprendido durante las últimas semanas. Tanto cómo te haga falta y solo si te hace falta. Esta vez serás tú el qué tome la decisión de qué tratamientos o limpiezas y visualizaciones serán mejor para tratar tus datos.
#
# Mínimo deberás importar las siguientes librerías, aunque te animo a explorar otras librerías nuevas.
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# Todo esto con el fin de poder verificar nuestra hipótesis. Sigue leyendo para más información.

# %% [markdown]
# ### Dataset

# %% [markdown]
# El dataset que utilizaremos para este mini-proyecto contiene datos sobre los ataques de tiburones en el mundo: localicación, fechas, tipología, especie causante, información sobre las víctimas, etc..
#
# Registrado por http://www.sharkattackfile.net/index.htm.
#
# Te lo podrás descargar en este enlace: https://www.kaggle.com/teajay/global-shark-attacks

# %% [markdown]
# ### Hipótesis
# Elige una o varias de estas hipótesis para desarrollar tu mini proyecto.
#
# Siéntete libre de establecer nuevas hipótesis que puedas validar o rechazar con tu análisis.

# %% [markdown]
# - El número de supervivientes ha aumentado con el paso de los años
# - Todos los ataques producidos en la India, ocurren a primera hora de la mañana
# - La mayoría de los ataques en los últimos 200 años tuvieron lugar en USA, Australia y Sudáfrica.
# - Las actividades con más riesgo de sufrir un ataque de tiburon son pescar y nadar.
# - La mayoría de los ataques de tiburón fueron fatales.
# - Los tiburones tienen especial predilección por los surferos.
# - Reunion Island es el lugar del mundo donde ocurren más ataques de tiburón en terminos relativos.
# - En Sudáfrica hay más ataques letales a mujeres que en Australia.

# %% [markdown]
# ### Github*
# *_Este punto es opcional pero MUY recomendable, ya que en el Proyecto de EDA será obligatorio_
#
# Crea un repositorio nuevo para guardar los archivos que necesites.
#
# Sigue la siguiente estructuras de carpetas:
#
#     - src -> aquí encontrarás el código, en este caso los notebooks que uses
#     - input -> aquí guardarás el dataset que utilices
#     - output -> aquí guardarás gráficas o datasets limpios, si los tuvieras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style = 'ticks')
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 0. Hipótesis y primer análisis

# %% [markdown]
# Las hipótesis que se van a tratar de refutar/validar son las siguientes:
# * Todos los ataques producidos en la India, ocurren a primera hora de la mañana.
# * Las actividades con más riesgo de sufrir un ataque de tiburón son pescar o nadar
# * La mayoría de los ataques de tiburón fueron fatales.
# * Reunion Island es el lugar del mundo donde ocurren más ataques de tiburón en terminos relativos.
# * Los tiburones tienen especial predilección por los surferos

# %%
sharks = pd.read_csv('../input/attacks.csv',encoding = "ISO-8859-1")
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
# Con qué datos contamos??
sharks.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
print("DataFrame shape:", sharks.shape, '\n')
print("DataFrame info:",sharks.info(), '\n')
print("DataFrame Columns:", sharks.columns, '\n')
print("type of each column:", sharks.dtypes, '\n')
print("Missing values in every colum", sharks.isna().sum())
# Out:
# DataFrame shape: (25723, 24)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB
# DataFrame info: None
#
# DataFrame Columns: Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')
#
# type of each column: Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object
#
# Missing values in every colum Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# Puede verse en los resultados de la celda anteriro que hay bastantes nulos en el DataFrame, así que, antes de hacer nada, lo primero es limpiarlo

# %% [markdown]
# ## 1. Limpieza del DataFrame
# Observando los resultados, se vaa a proceder de la siguiente manera:
# * Las columnas `Unnamed: 22` y `Unnamed: 23` se eliminan completamente del data set por no aportar valor ninguno.
# * También hay columnas como `Age`, `Time`, `Species` que tienen bastantes nulos (comparándolo con el resto de columnas)
# * Se eliminarán los registros con nulos a lo largo de toda la fila (si exiten)
# * Se comprobará que no hay duplicados

# %%
#Eliminar las dos últimas columnas
sharks = sharks.loc[:, 'Date': 'original order']
sharks.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#    ... Fatal (Y/N)           Time         Species   \
# 0  ...           N          18h00      White shark
# 1  ...           N  14h00  -15h00              NaN
# 2  ...           N          07h45              NaN
# 3  ...           N            NaN        2 m shark
# 4  ...           N            NaN  Tiger shark, 3m
#
#            Investigator or Source                       pdf  \
# 0                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order
# 0    2018.06.25         6303.0
# 1    2018.06.18         6302.0
# 2    2018.06.09         6301.0
# 3    2018.06.08         6300.0
# 4    2018.06.04         6299.0
#
# [5 rows x 21 columns]

# %%
#Limpieza de los registros sin datos
print("Antes de limpiar los registros sin datos el tamaño del DataFrame es:",sharks.shape, "\n")
print("Después de limpiar los registros el tamaño del Dataframe es:",sharks.dropna(how='all').shape, "\n")
print('Se ha eliminado', sharks.shape[0] - sharks.dropna(how='all').shape[0], 'filas')
# Out:
# Antes de limpiar los registros sin datos el tamaño del DataFrame es: (25723, 21)
#
# Después de limpiar los registros el tamaño del Dataframe es: (6309, 21)
#
# Se ha eliminado 19414 filas

# %% [markdown]
# Como se puede ver, se han eliminado 19414 filas que no contenían datos, por ello, se procede a realizar un cambio permanente con 'inplace', y se guardará ese dataframe en un nuevo csv para poder realizar tratamientos posteriores. Pero antes, continuamos con la limpieza.

# %%
df_sharks = sharks.dropna(how='all')

# %%
df_sharks.tail(20)
# Out:
#                                                    Date  Year        Type  \
# 6289  No date (3 days after preceding incident) & pr...   0.0  Unprovoked
# 6290                                 Before 19-Jul-1913   0.0  Unprovoked
# 6291                                        Before 1911   0.0  Unprovoked
# 6292                                         Circa 1862   0.0  Unprovoked
# 6293                                        Before 1906   0.0  Unprovoked
# 6294                                        Before 1906   0.0  Unprovoked
# 6295                                        Before 1906   0.0  Unprovoked
# 6296                                        Before 1906   0.0  Unprovoked
# 6297                                        Before 1903   0.0  Unprovoked
# 6298                                        Before 1903   0.0  Unprovoked
# 6299                                          1900-1905   0.0  Unprovoked
# 6300                                          1883-1889   0.0  Unprovoked
# 6301                                          1845-1853   0.0  Unprovoked
# 6302                                                NaN   NaN         NaN
# 6303                                                NaN   NaN         NaN
# 6304                                                NaN   NaN         NaN
# 6305                                                NaN   NaN         NaN
# 6306                                                NaN   NaN         NaN
# 6307                                                NaN   NaN         NaN
# 6308                                                NaN   NaN         NaN
#
#                  Country               Area  \
# 6289        SOUTH AFRICA      KwaZulu-Natal
# 6290        SOUTH AFRICA      KwaZulu-Natal
# 6291               ASIA?                NaN
# 6292                 USA             Hawaii
# 6293           AUSTRALIA                NaN
# 6294           AUSTRALIA                NaN
# 6295           AUSTRALIA                NaN
# 6296           AUSTRALIA    New South Wales
# 6297           AUSTRALIA  Western Australia
# 6298           AUSTRALIA  Western Australia
# 6299                 USA     North Carolina
# 6300              PANAMA                NaN
# 6301  CEYLON (SRI LANKA)   Eastern Province
# 6302                 NaN                NaN
# 6303                 NaN                NaN
# 6304                 NaN                NaN
# 6305                 NaN                NaN
# 6306                 NaN                NaN
# 6307                 NaN                NaN
# 6308                 NaN                NaN
#
#                                  Location      Activity  \
# 6289                               Durban       Fishing
# 6290                               Durban        Wading
# 6291                                  NaN      Swimming
# 6292                                 Puna           NaN
# 6293                                  NaN       Fishing
# 6294                                  NaN       Fishing
# 6295                                  NaN       Fishing
# 6296                                           Swimming
# 6297                          Roebuck Bay        Diving
# 6298                                  NaN  Pearl diving
# 6299                       Ocracoke Inlet      Swimming
# 6300                 Panama Bay 8ºN, 79ºW           NaN
# 6301  Below the English fort, Trincomalee      Swimming
# 6302                                  NaN           NaN
# 6303                                  NaN           NaN
# 6304                                  NaN           NaN
# 6305                                  NaN           NaN
# 6306                                  NaN           NaN
# 6307                                  NaN           NaN
# 6308                                  NaN           NaN
#
#                        Name Sex   Age  ... Fatal (Y/N) Time  \
# 6289     a native fisherman    M  NaN  ...           Y  NaN
# 6290       a young Scotsman    M  NaN  ...           Y  NaN
# 6291             Mr. Masury    M  NaN  ...           N  NaN
# 6292           A "chiefess"    F  NaN  ...           N  NaN
# 6293                    boy    M  NaN  ...           Y  NaN
# 6294              fisherman    M  NaN  ...           Y  NaN
# 6295              fisherman    M  NaN  ...           Y  NaN
# 6296               Arab boy    M  NaN  ...           Y  NaN
# 6297                   male    M  NaN  ...           Y  NaN
# 6298                  Ahmun    M  NaN  ...           Y  NaN
# 6299  Coast Guard personnel    M  NaN  ...           Y  NaN
# 6300        Jules Patterson    M  NaN  ...           Y  NaN
# 6301                   male    M   15  ...           Y  NaN
# 6302                    NaN  NaN  NaN  ...         NaN  NaN
# 6303                    NaN  NaN  NaN  ...         NaN  NaN
# 6304                    NaN  NaN  NaN  ...         NaN  NaN
# 6305                    NaN  NaN  NaN  ...         NaN  NaN
# 6306                    NaN  NaN  NaN  ...         NaN  NaN
# 6307                    NaN  NaN  NaN  ...         NaN  NaN
# 6308                    NaN  NaN  NaN  ...         NaN  NaN
#
#                                                Species   \
# 6289                                                NaN
# 6290                                                NaN
# 6291                                                NaN
# 6292                                                NaN
# 6293                                       Blue pointer
# 6294                                       Blue pointer
# 6295                                      Blue pointers
# 6296  Said to involve a grey nurse shark that leapt ...
# 6297                                                NaN
# 6298                                                NaN
# 6299                                                NaN
# 6300                                                NaN
# 6301                                                NaN
# 6302                                                NaN
# 6303                                                NaN
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                                  Investigator or Source  \
# 6289                       Rural New Yorker, 7/19/1913
# 6290                        Rural New Yorker, 7/19/1913
# 6291          Ref. J. T. Dubois in N.Y. Sun, 3/19/1911
# 6292                                   Captain W. Young
# 6293  NY Sun, 9/9/1906, referring to account by Loui...
# 6294  NY Sun, 9/9/1906, referring to account by Loui...
# 6295  NY Sun, 9/9/1906, referring to account by Loui...
# 6296  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 6297                   H. Taunton; N. Bartlett,  p. 234
# 6298              H. Taunton; N. Bartlett,  pp. 233-234
# 6299               F. Schwartz, p.23; C. Creswell, GSAF
# 6300                                The Sun, 10/20/1938
# 6301                                         S.W. Baker
# 6302                                                NaN
# 6303                                                NaN
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                                       pdf  \
# 6289  ND-0013-Durban-native-fisherman.pdf
# 6290          ND-0012-Durban-Scotsman.pdf
# 6291                   ND-0011-Masury.pdf
# 6292              ND-0010-Puna Hawaii.pdf
# 6293            ND-0009-boy-Australia.pdf
# 6294     ND-0008-Fisherman2-Australia.pdf
# 6295    ND-0007 - Fisherman-Australia.pdf
# 6296         ND-0006-ArabBoy-Prymount.pdf
# 6297               ND-0005-RoebuckBay.pdf
# 6298                    ND-0004-Ahmun.pdf
# 6299       ND-0003-Ocracoke_1900-1905.pdf
# 6300           ND-0002-JulesPatterson.pdf
# 6301                   ND-0001-Ceylon.pdf
# 6302                                  NaN
# 6303                                  NaN
# 6304                                  NaN
# 6305                                  NaN
# 6306                                  NaN
# 6307                                  NaN
# 6308                                  NaN
#
#                                            href formula  \
# 6289  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6290  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6291  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6292  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6293  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6294  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6295  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6302                                                NaN
# 6303                                                NaN
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                                                    href Case Number.1  \
# 6289  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0013
# 6290  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0012
# 6291  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0011
# 6292  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0010
# 6293  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0009
# 6294  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0008
# 6295  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0007
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
# 6302                                                NaN           NaN
# 6303                                                NaN           NaN
# 6304                                                NaN           NaN
# 6305                                                NaN           NaN
# 6306                                                NaN           NaN
# 6307                                                NaN           NaN
# 6308                                                NaN           NaN
#
#      Case Number.2 original order
# 6289       ND.0013           14.0
# 6290       ND.0012           13.0
# 6291       ND.0011           12.0
# 6292       ND.0010           11.0
# 6293       ND.0009           10.0
# 6294       ND.0008            9.0
# 6295       ND.0007            8.0
# 6296       ND.0006            7.0
# 6297       ND.0005            6.0
# 6298       ND.0004            5.0
# 6299       ND.0003            4.0
# 6300       ND.0002            3.0
# 6301       ND.0001            2.0
# 6302           NaN         6304.0
# 6303           NaN         6305.0
# 6304           NaN         6306.0
# 6305           NaN         6307.0
# 6306           NaN         6308.0
# 6307           NaN         6309.0
# 6308           NaN         6310.0
#
# [20 rows x 21 columns]

# %%
df_sharks.loc[:,'Age':'Fatal (Y/N)']
# Out:
#       Age                                             Injury Fatal (Y/N)
# 0      57  No injury to occupant, outrigger canoe and pad...           N
# 1      11                         Minor injury to left thigh           N
# 2      48       Injury to left lower leg from surfboard skeg           N
# 3     NaN                          Minor injury to lower leg           N
# 4     NaN  Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...   ...                                                ...         ...
# 6304  NaN                                                NaN         NaN
# 6305  NaN                                                NaN         NaN
# 6306  NaN                                                NaN         NaN
# 6307  NaN                                                NaN         NaN
# 6308  NaN                                                NaN         NaN
#
# [6309 rows x 3 columns]

# %% [markdown]
# Viendo el DataFrame como está, se puede ver que una gran parte de las últimas filas (7) contienen muchos nulos.
#
# Por eso aplico un 'thresh' a este DataFrame.
#
# Existen 21 columnas, de manera que eliminaré los registros que solo tengan 2 valores no nulos. Esto supone algo menos de un 10% de valores no nulos en cada registro, y serán considerados como no nulos. En otras palabras, para considerar un registro (caso) como válido para poder realizar comparaciones, deberá contar con almenos, el 10% de la información máxima que aporta el DataFrame.

# %%
clean_sharks = df_sharks.dropna(thresh=2)

# %%
clean_sharks
# Out:
#              Date    Year        Type             Country               Area  \
# 0     25-Jun-2018  2018.0     Boating                 USA         California
# 1     18-Jun-2018  2018.0  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018.0     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018  2018.0    Provoked              MEXICO             Colima
# ...           ...     ...         ...                 ...                ...
# 6297  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0             Oceanside, San Diego County      Paddling
# 1          St. Simon Island, Glynn County      Standing
# 2                            Habush, Oahu       Surfing
# 3                      Arrawarra Headland       Surfing
# 4                                La Ticla   Free diving
# ...                                   ...           ...
# 6297                          Roebuck Bay        Diving
# 6298                                  NaN  Pearl diving
# 6299                       Ocracoke Inlet      Swimming
# 6300                 Panama Bay 8ºN, 79ºW           NaN
# 6301  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  ... Fatal (Y/N)           Time  \
# 0               Julie Wolfe    F   57  ...           N          18h00
# 1           Adyson McNeely     F   11  ...           N  14h00  -15h00
# 2               John Denges    M   48  ...           N          07h45
# 3                      male    M  NaN  ...           N            NaN
# 4            Gustavo Ramos     M  NaN  ...           N            NaN
# ...                     ...  ...  ...  ...         ...            ...
# 6297                   male    M  NaN  ...           Y            NaN
# 6298                  Ahmun    M  NaN  ...           Y            NaN
# 6299  Coast Guard personnel    M  NaN  ...           Y            NaN
# 6300        Jules Patterson    M  NaN  ...           Y            NaN
# 6301                   male    M   15  ...           Y            NaN
#
#              Species                  Investigator or Source  \
# 0         White shark                       R. Collier, GSAF
# 1                 NaN         K.McMurray, TrackingSharks.com
# 2                 NaN         K.McMurray, TrackingSharks.com
# 3           2 m shark                         B. Myatt, GSAF
# 4     Tiger shark, 3m                              A .Kipper
# ...               ...                                    ...
# 6297              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300              NaN                    The Sun, 10/20/1938
# 6301              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order
# 0       2018.06.25         6303.0
# 1       2018.06.18         6302.0
# 2       2018.06.09         6301.0
# 3       2018.06.08         6300.0
# 4       2018.06.04         6299.0
# ...            ...            ...
# 6297       ND.0005            6.0
# 6298       ND.0004            5.0
# 6299       ND.0003            4.0
# 6300       ND.0002            3.0
# 6301       ND.0001            2.0
#
# [6302 rows x 21 columns]

# %% [markdown]
# Antes de guardarlo en un csv, vulvo a analizar los datos:

# %%
sns.heatmap(clean_sharks.isnull(), yticklabels=False, cbar = False, cmap='tab20c_r')
plt.title('Missing Data')
# Out:
# Text(0.5, 1.0, 'Missing Data')

# %% [markdown]
# Finalizo este apartado creando un nuevo csv que utilizaré para el análisis.

# %%
clean_sharks.to_csv('../output/attacks_cleaned.csv', index=False)

# %% [markdown]
# ## 2. Análisis de los datos

# %% [markdown]
# Como se mencionó en el [*apartado 0*](#0.-Hipótesis-y-primer-análisis) son las siguientes:
# * Todos los ataques producidos en la India, ocurren a primera hora de la mañana.
# * Las actividades con más riesgo de sufrir un ataque de tiburón son pescar o nadar
# * La mayoría de los ataques de tiburón fueron fatales.
# * Reunion Island es el lugar del mundo donde ocurren más ataques de tiburón en terminos relativos.
# * Los tiburones tienen especial predilección por los surferos

# %%
# Importo el dataframe
df_attacks = pd.read_csv('../output/attacks_cleaned.csv')
df_attacks.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#    ... Fatal (Y/N)           Time         Species   \
# 0  ...           N          18h00      White shark
# 1  ...           N  14h00  -15h00              NaN
# 2  ...           N          07h45              NaN
# 3  ...           N            NaN        2 m shark
# 4  ...           N            NaN  Tiger shark, 3m
#
#            Investigator or Source                       pdf  \
# 0                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order
# 0    2018.06.25         6303.0
# 1    2018.06.18         6302.0
# 2    2018.06.09         6301.0
# 3    2018.06.08         6300.0
# 4    2018.06.04         6299.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2.1. Todos los ataques producidos en la India, ocurren a primera hora de la mañana

# %%
print("Ataques registrados en la India:", df_attacks.loc[df_attacks['Country']=='INDIA', ['Time']].shape[0])
print("Casos que no han registrado la hora del ataque:", df_attacks.loc[df_attacks['Country']=='INDIA', ['Time']].isnull().sum()[0])
df_attacks.loc[(df_attacks['Country']=='INDIA') & (df_attacks['Time']!='NaN'), ['Time']].dropna()
# Out:
# Ataques registrados en la India: 40
# Casos que no han registrado la hora del ataque: 32
#               Time
# 5104         13h00
# 5818         11h00
# 5821         12h00
# 5822         10h00
# 5922  Before 10h30
# 6090       Evening
# 6091   17h00-18h00
# 6113       Evening

# %% [markdown]
# Con la tabla mostrada anteriormente, se puede refutar la hipótesis fácilmente sin necesidad de gráficos.
#
# Además, la hipótesis afirmaba que 'TODOS' los ataques se producían a primera hora de la mañana, de manera que con un único caso que no ocurriera a esa hora, negaría la hipótesis.

# %% [markdown]
# ### 2.2. Las actividades con más riesgo de sufrir un ataque de tiburón son pescar o nadar

# %%
df_attacks['Activity'].value_counts() #Así observo los datos recogidos en esta columna
# Out:
# Surfing                                                      971
# Swimming                                                     869
# Fishing                                                      431
# Spearfishing                                                 333
# Bathing                                                      162
#                                                             ...
# Human head found in shark caught by British steamer Syria      1
# Swimming or paddle boarding                                    1
# Free diving for molluscs                                       1
# Surfing, pushing board ashore                                  1
# Spearfishing, but swimming on surface                          1
# Name: Activity, Length: 1532, dtype: int64

# %%
#Creo una columna 'Activity2' para homogneizar algo más los tipos de actividades
#Hay actividades como paddle surf, que son modalidades del surf y las incluiré como tal
df_attacks['Activity2']=df_attacks[['Activity']] 
df_attacks.head()
# Out:
#           Date    Year        Type    Country             Area  \
# 0  25-Jun-2018  2018.0     Boating        USA       California
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#    ...           Time         Species           Investigator or Source  \
# 0  ...          18h00      White shark                R. Collier, GSAF
# 1  ...  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2  ...          07h45              NaN  K.McMurray, TrackingSharks.com
# 3  ...            NaN        2 m shark                  B. Myatt, GSAF
# 4  ...            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order    Activity2
# 0    2018.06.25         6303.0     Paddling
# 1    2018.06.18         6302.0     Standing
# 2    2018.06.09         6301.0      Surfing
# 3    2018.06.08         6300.0      Surfing
# 4    2018.06.04         6299.0  Free diving
#
# [5 rows x 22 columns]

# %%
df_attacks.loc[df_attacks['Activity2'] == 'Paddling', 'Activity'] = 'Surfing'

# %%
df_attacks['Activity'].value_counts()
# Out:
# Surfing                                                                                                                                               974
# Swimming                                                                                                                                              869
# Fishing                                                                                                                                               431
# Spearfishing                                                                                                                                          333
# Bathing                                                                                                                                               162
#                                                                                                                                                      ...
# Human head found in shark caught by British steamer Syria                                                                                               1
# Free diving for molluscs                                                                                                                                1
# Surfing, pushing board ashore                                                                                                                           1
# Spearfishing with Joe Turner (24). Shark attracted to speared halibut on belt of one diver, tried to bite Ides speargun & he shot it in the mouth      1
# Spearfishing, but swimming on surface                                                                                                                   1
# Name: Activity, Length: 1531, dtype: int64

# %%
df_attacks.loc[df_attacks['Activity2'].str.contains("Surfing")==True, ['Activity2']] = 'Surfing'
df_attacks.loc[df_attacks['Activity2'].str.contains("surfing")==True, ['Activity2']] = 'Surfing'

# %%
df_attacks['Activity2'].value_counts()
# Out:
# Surfing                                                                        1127
# Swimming                                                                        869
# Fishing                                                                         431
# Spearfishing                                                                    333
# Bathing                                                                         162
#                                                                                ...
# Standing / Wading                                                                 1
# boat capsized during filming                                                      1
# Fishing, shark caught in his net                                                  1
# American minesweeper USS YMS-472 foundered in a typhoon - swimming to shore       1
# Spearfishing, but swimming on surface                                             1
# Name: Activity2, Length: 1471, dtype: int64

# %%
ax = sns.catplot(x = 'Activity2',data = df_attacks, kind = 'count', order=df_attacks.Activity.value_counts().iloc[:5].index,
                palette = 'summer')

ax.set_xticklabels(rotation=45, ha='right')
ax.set(title = 'Shark attacks per activity', ylabel = 'Nb of attacks')

# %% [markdown]
# El gráfico mostrado incluye el top 5 de actividades con más ataques registrados.
# Atendiendo a los resultados se puede negar que las actividades con mayor riesgo de sufrir un ataque de tiburón son pescar y nadar, ya que que la actividad con mayor número de ataques registrados es el surf. Sin embargo, cabe destacar que sería beneficioso saber el número total de personas que realizan esas actividades.

# %% [markdown]
# ### 2.3. La mayoría de los ataques de tiburón fueron fatales

# %%
df_attacks['Fatal (Y/N)'].value_counts() #Así observo los datos recogidos en esta columna
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# N             1
# 2017          1
# M             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# ### 2.4. Los tiburones tienen especial predilección por los surferos
